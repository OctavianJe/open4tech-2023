# %%
# !pip install transformers==4.29.0
# Out:
# ...
#   Using cached transformers-4.29.0-py3-none-any.whl (7.1 MB)
# ...
#                                               0.0/236.8 kB ? eta -:--:--
#      ----------                              61.4/236.8 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 236.8/236.8 kB 2.9 MB/s eta 0:00:00
# ...
#                                               0.0/15.0 MB ? eta -:--:--
#                                               0.1/15.0 MB 2.6 MB/s eta 0:00:06
#                                               0.4/15.0 MB 5.8 MB/s eta 0:00:03
#      -                                        0.7/15.0 MB 5.3 MB/s eta 0:00:03
#      --                                       1.0/15.0 MB 5.8 MB/s eta 0:00:03
#      ---                                      1.3/15.0 MB 6.1 MB/s eta 0:00:03
#      ----                                     1.7/15.0 MB 6.3 MB/s eta 0:00:03
#      -----                                    2.0/15.0 MB 6.3 MB/s eta 0:00:03
# ...

# %%
# !pip install git+https://github.com/huggingface/accelerate
# Out:
# ...
#   Cloning https://github.com/huggingface/accelerate to c:\users\o.g.ploscaru\appdata\local\temp\pip-req-build-bqvldflx
#   Resolved https://github.com/huggingface/accelerate to commit d141b4ce794227450a105b7281611c7980e5b3d6
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached torch-2.0.1-cp311-cp311-win_amd64.whl (172.3 MB)
# ...
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# ...
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# ...
#   Created wheel for accelerate: filename=accelerate-0.21.0.dev0-py3-none-any.whl size=236215 sha256=66c8d4bcaa4a2abb5f27a8f9535ea8701ea562d44f1a37da567394aaaa643281
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

# Load the pretrained model
tokenizer = AutoTokenizer.from_pretrained("jordiclive/flan-t5-3b-summarizer")
model = AutoModelForSeq2SeqLM.from_pretrained("jordiclive/flan-t5-3b-summarizer")

# %%
from transformers import pipeline

summarizer = pipeline("summarization", "jordiclive/flan-t5-3b-summarizer", torch_dtype=torch.bfloat16)

raw_document = 'The tower is 324 metres (1,063 ft) tall, about the same height as an 81-storey building, and the tallest structure in Paris. Its base is square, measuring 125 metres (410 ft) on each side. During its construction, the Eiffel Tower surpassed the Washington Monument to become the tallest man-made structure in the world, a title it held for 41 years until the Chrysler Building in New York City was finished in 1930. It was the first structure to reach a height of 300 metres. Due to the addition of a broadcasting aerial at the top of the tower in 1957, it is now taller than the Chrysler Building by 5.2 metres (17 ft). Excluding transmitters, the Eiffel Tower is the second tallest free-standing structure in France after the Millau Viaduct.'
prompt = "Produce an article summary of the following news article:"
results = summarizer(
        f"{prompt} {raw_document}",
        num_beams=5,
        min_length=5,
        no_repeat_ngram_size=3,
        truncation=True,
        max_length=100,
    )

# %%
results
# Out:
# [{'summary_text': 'The tower is 324 metres (1,063 ft) tall, about the same height as an 81-storey building . During its construction, the Eiffel Tower surpassed the Washington Monument to become the tallest man-made structure in the world.'}]

# %%
# !python main.py
